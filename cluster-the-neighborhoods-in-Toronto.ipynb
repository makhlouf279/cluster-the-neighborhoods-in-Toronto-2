# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import numpy as np
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
from pandas.io.json import json_normalize  # tranform JSON file into a pandas dataframe

import folium # map rendering library

# import k-means from clustering stage
from sklearn.cluster import KMeans

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
source = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M").text
soup = BeautifulSoup(source, 'lxml')

table = soup.find("table")
table_rows = table.tbody.find_all("tr")

res = []
for tr in table_rows:
    td = tr.find_all("td")
    row = [tr.text for tr in td]
    
    # Only process the cells that have an assigned borough. Ignore cells with a borough that is Not assigned.
    if row != [] and row[1] != "Not assigned":
        # If a cell has a borough but a "Not assigned" neighborhood, then the neighborhood will be the same as the borough.
        if "Not assigned" in row[2]: 
            row[2] = row[1]
        res.append(row)

# Dataframe with 3 columns
df = pd.DataFrame(res, columns = ["PostalCode", "Borough", "Neighborhood"])
df.head()
# Out:
#   PostalCode             Borough                 Neighborhood
# 0      M1A\n      Not assigned\n               Not assigned\n
# 1      M2A\n      Not assigned\n               Not assigned\n
# 2      M3A\n        North York\n                  Parkwoods\n
# 3      M4A\n        North York\n           Victoria Village\n
# 4      M5A\n  Downtown Toronto\n  Regent Park, Harbourfront\n

# %%
pip install lxml
# Out:
# Requirement already satisfied: lxml in c:\users\jesuis\anaconda3\lib\site-packages (4.6.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Remove "\n" at the end of each string in the Neighborhood column
df["Neighborhood"] = df["Neighborhood"].str.replace("\n","")
df.head()
# Out:
#   PostalCode             Borough               Neighborhood
# 0      M1A\n      Not assigned\n               Not assigned
# 1      M2A\n      Not assigned\n               Not assigned
# 2      M3A\n        North York\n                  Parkwoods
# 3      M4A\n        North York\n           Victoria Village
# 4      M5A\n  Downtown Toronto\n  Regent Park, Harbourfront

# %%
#Remove "\n" at the end of each string in the PostalCode column
df["PostalCode"] = df["PostalCode"].str.replace("\n","")
df.head()
# Out:
#   PostalCode             Borough               Neighborhood
# 0        M1A      Not assigned\n               Not assigned
# 1        M2A      Not assigned\n               Not assigned
# 2        M3A        North York\n                  Parkwoods
# 3        M4A        North York\n           Victoria Village
# 4        M5A  Downtown Toronto\n  Regent Park, Harbourfront

# %%
#Remove "\n" at the end of each string in the Borough column
df["Borough"] = df["Borough"].str.replace("\n","")
df.head()
# Out:
#   PostalCode           Borough               Neighborhood
# 0        M1A      Not assigned               Not assigned
# 1        M2A      Not assigned               Not assigned
# 2        M3A        North York                  Parkwoods
# 3        M4A        North York           Victoria Village
# 4        M5A  Downtown Toronto  Regent Park, Harbourfront

# %%
#Group all neighborhoods with the same postal code
df = df.groupby(["PostalCode", "Borough"])["Neighborhood"].apply(", ".join).reset_index()
df.head(10)
# Out:
#   PostalCode       Borough                                     Neighborhood
# 0        M1A  Not assigned                                     Not assigned
# 1        M1B   Scarborough                                   Malvern, Rouge
# 2        M1C   Scarborough           Rouge Hill, Port Union, Highland Creek
# 3        M1E   Scarborough                Guildwood, Morningside, West Hill
# 4        M1G   Scarborough                                           Woburn
# 5        M1H   Scarborough                                        Cedarbrae
# 6        M1J   Scarborough                              Scarborough Village
# 7        M1K   Scarborough      Kennedy Park, Ionview, East Birchmount Park
# 8        M1L   Scarborough                  Golden Mile, Clairlea, Oakridge
# 9        M1M   Scarborough  Cliffside, Cliffcrest, Scarborough Village West

# %%
print("Shape: ", df.shape)
# Out:
# Shape:  (180, 3)

# %%
#We are not able to get the geohraphical coordinates of the neighborhoods using the Geocoder package, we use the given csv file instead.
df_geo_coor = pd.read_csv("http://cocl.us/Geospatial_data")
df_geo_coor.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
#We need to couple 2 dataframes "df" and "df_geo_coor" into one dataframe.

df_toronto = pd.merge(df, df_geo_coor, how='left', left_on = 'PostalCode', right_on = 'Postal Code')
# remove the "Postal Code" column
df_toronto.drop("Postal Code", axis=1, inplace=True)
df_toronto.head()
# Out:
#   PostalCode       Borough                            Neighborhood   Latitude  \
# 0        M1A  Not assigned                            Not assigned        NaN
# 1        M1B   Scarborough                          Malvern, Rouge  43.806686
# 2        M1C   Scarborough  Rouge Hill, Port Union, Highland Creek  43.784535
# 3        M1E   Scarborough       Guildwood, Morningside, West Hill  43.763573
# 4        M1G   Scarborough                                  Woburn  43.770992
#
#    Longitude
# 0        NaN
# 1 -79.194353
# 2 -79.160497
# 3 -79.188711
# 4 -79.216917

# %%
#remove  de nan values
index_with_nan = df_toronto.index[df_toronto.isnull().any(axis=1)]
df_toronto.drop(index_with_nan,0, inplace=True)
df_toronto.head(50)
# Out:
#    PostalCode          Borough  \
# 1         M1B      Scarborough
# 2         M1C      Scarborough
# 3         M1E      Scarborough
# 4         M1G      Scarborough
# 5         M1H      Scarborough
# 6         M1J      Scarborough
# 7         M1K      Scarborough
# 8         M1L      Scarborough
# 9         M1M      Scarborough
# 10        M1N      Scarborough
# 11        M1P      Scarborough
# 12        M1R      Scarborough
# 13        M1S      Scarborough
# 14        M1T      Scarborough
# 15        M1V      Scarborough
# 16        M1W      Scarborough
# 17        M1X      Scarborough
# 25        M2H       North York
# 26        M2J       North York
# 27        M2K       North York
# 28        M2L       North York
# 29        M2M       North York
# 30        M2N       North York
# 31        M2P       North York
# 32        M2R       North York
# 40        M3A       North York
# 41        M3B       North York
# 42        M3C       North York
# 45        M3H       North York
# 46        M3J       North York
# 47        M3K       North York
# 48        M3L       North York
# 49        M3M       North York
# 50        M3N       North York
# 60        M4A       North York
# 61        M4B        East York
# 62        M4C        East York
# 63        M4E     East Toronto
# 64        M4G        East York
# 65        M4H        East York
# 66        M4J        East York
# 67        M4K     East Toronto
# 68        M4L     East Toronto
# 69        M4M     East Toronto
# 70        M4N  Central Toronto
# 71        M4P  Central Toronto
# 72        M4R  Central Toronto
# 73        M4S  Central Toronto
# 74        M4T  Central Toronto
# 75        M4V  Central Toronto
#
#                                          Neighborhood   Latitude  Longitude
# 1                                      Malvern, Rouge  43.806686 -79.194353
# 2              Rouge Hill, Port Union, Highland Creek  43.784535 -79.160497
# 3                   Guildwood, Morningside, West Hill  43.763573 -79.188711
# 4                                              Woburn  43.770992 -79.216917
# 5                                           Cedarbrae  43.773136 -79.239476
# 6                                 Scarborough Village  43.744734 -79.239476
# 7         Kennedy Park, Ionview, East Birchmount Park  43.727929 -79.262029
# 8                     Golden Mile, Clairlea, Oakridge  43.711112 -79.284577
# 9     Cliffside, Cliffcrest, Scarborough Village West  43.716316 -79.239476
# 10                        Birch Cliff, Cliffside West  43.692657 -79.264848
# 11  Dorset Park, Wexford Heights, Scarborough Town...  43.757410 -79.273304
# 12                                  Wexford, Maryvale  43.750072 -79.295849
# 13                                          Agincourt  43.794200 -79.262029
# 14            Clarks Corners, Tam O'Shanter, Sullivan  43.781638 -79.304302
# 15  Milliken, Agincourt North, Steeles East, L'Amo...  43.815252 -79.284577
# 16                      Steeles West, L'Amoreaux West  43.799525 -79.318389
# 17                                        Upper Rouge  43.836125 -79.205636
# 25                                  Hillcrest Village  43.803762 -79.363452
# 26                       Fairview, Henry Farm, Oriole  43.778517 -79.346556
# 27                                    Bayview Village  43.786947 -79.385975
# 28                           York Mills, Silver Hills  43.757490 -79.374714
# 29                            Willowdale, Newtonbrook  43.789053 -79.408493
# 30                        Willowdale, Willowdale East  43.770120 -79.408493
# 31                                    York Mills West  43.752758 -79.400049
# 32                        Willowdale, Willowdale West  43.782736 -79.442259
# 40                                          Parkwoods  43.753259 -79.329656
# 41                                          Don Mills  43.745906 -79.352188
# 42                                          Don Mills  43.725900 -79.340923
# 45    Bathurst Manor, Wilson Heights, Downsview North  43.754328 -79.442259
# 46                    Northwood Park, York University  43.767980 -79.487262
# 47                                          Downsview  43.737473 -79.464763
# 48                                          Downsview  43.739015 -79.506944
# 49                                          Downsview  43.728496 -79.495697
# 50                                          Downsview  43.761631 -79.520999
# 60                                   Victoria Village  43.725882 -79.315572
# 61                    Parkview Hill, Woodbine Gardens  43.706397 -79.309937
# 62                                   Woodbine Heights  43.695344 -79.318389
# 63                                        The Beaches  43.676357 -79.293031
# 64                                            Leaside  43.709060 -79.363452
# 65                                   Thorncliffe Park  43.705369 -79.349372
# 66      East Toronto, Broadview North (Old East York)  43.685347 -79.338106
# 67                       The Danforth West, Riverdale  43.679557 -79.352188
# 68                     India Bazaar, The Beaches West  43.668999 -79.315572
# 69                                    Studio District  43.659526 -79.340923
# 70                                      Lawrence Park  43.728020 -79.388790
# 71                                   Davisville North  43.712751 -79.390197
# 72                 North Toronto West,  Lawrence Park  43.715383 -79.405678
# 73                                         Davisville  43.704324 -79.388790
# 74                        Moore Park, Summerhill East  43.689574 -79.383160
# 75  Summerhill West, Rathnelly, South Hill, Forest...  43.686412 -79.400049

# %%
#Get the latitude and longitude values of Toronto.
address = "Toronto, ON"

geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto city are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto city are 43.6534817, -79.3839347.

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Add markers to the map.
for lat, lng, borough, neighborhood in zip(
        df_toronto['Latitude'], 
        df_toronto['Longitude'], 
        df_toronto['Borough'], 
        df_toronto['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  

map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Map of a part of Toronto City
#We are going to work with only the boroughs that contain the word "Toronto".
df_toronto_denc = df_toronto[df_toronto['Borough'].str.contains("Toronto")].reset_index(drop=True)
df_toronto_denc.head()
# Out:
#   PostalCode          Borough                    Neighborhood   Latitude  \
# 0        M4E     East Toronto                     The Beaches  43.676357
# 1        M4K     East Toronto    The Danforth West, Riverdale  43.679557
# 2        M4L     East Toronto  India Bazaar, The Beaches West  43.668999
# 3        M4M     East Toronto                 Studio District  43.659526
# 4        M4N  Central Toronto                   Lawrence Park  43.728020
#
#    Longitude
# 0 -79.293031
# 1 -79.352188
# 2 -79.315572
# 3 -79.340923
# 4 -79.388790

# %%
#map and the markers for this region
map_toronto_denc = folium.Map(location=[latitude, longitude], zoom_start=12)
for lat, lng, borough, neighborhood in zip(
        df_toronto_denc['Latitude'], 
        df_toronto_denc['Longitude'], 
        df_toronto_denc['Borough'], 
        df_toronto_denc['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto_denc)  

map_toronto_denc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
